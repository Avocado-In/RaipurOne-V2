# %% [markdown]
# # AI experiments for Smart Grievance Management
#
# This notebook is the dedicated place for future ML work. The web app and backend will call into the trained model later, but for now the notebook remains a standalone experimentation workspace.

# %%
import pandas as pd
import numpy as np

sample_data = pd.DataFrame({
    'title': ['Streetlight outage', 'Garbage accumulation', 'Water leakage'],
    'category': ['lighting', 'sanitation', 'water'],
    'priority': ['high', 'medium', 'high']
})

sample_data.head()
